# %% [markdown]
# <a href="https://colab.research.google.com/github/danielmlow/tutorials/blob/main/sentiment_analysis_emotion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Emotion classification (pre-trained)

# %%
# !pip install -q transformers
from transformers import pipeline
sentiment_pipeline = pipeline(model = "bhadresh-savani/distilbert-base-uncased-emotion")
# Out:
#      |████████████████████████████████| 4.2 MB 13.4 MB/s
#      |████████████████████████████████| 596 kB 57.1 MB/s
#      |████████████████████████████████| 6.6 MB 58.5 MB/s
#      |████████████████████████████████| 84 kB 1.4 MB/s
# Downloading:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/768 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/291 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
import pandas as pd


def huggingface_output_2_df(output_dict, feature_names = ['sadness', 'joy', 'love', 'anger', 'fear', 'surprise']):
  feature_vectors = []
  for doc in output_dict:
    feature_vectors_doc = []
    for feature in doc:
      feature_vectors_doc.append(feature.get('score'))
    feature_vectors.append(feature_vectors_doc)
  feature_vectors = pd.DataFrame(feature_vectors, columns = feature_names)
  return feature_vectors

# %%
docs = ['I am happy', 'I have happy, but worried about tomorrow', "I'm miserable", "I'm sad, but hopeful", "Don't talk to me like that!", "Really? I'm shocked!"]
output_dict = sentiment_pipeline(list(docs), return_all_scores=True)
feature_vectors = huggingface_output_2_df(output_dict, feature_names = ['distilbert_sadness', 'distilbert_joy', 'distilbert_love', 'distilbert_anger', 'distilbert_fear', 'distilbert_surprise'])
feature_vectors
# Out:
#    distilbert_sadness  distilbert_joy  distilbert_love  distilbert_anger  \
# 0            0.000544        0.998437         0.000456          0.000262
# 1            0.035586        0.286979         0.005680          0.138778
# 2            0.998362        0.000282         0.000180          0.000899
# 3            0.067532        0.920843         0.007467          0.002613
# 4            0.003571        0.002445         0.000491          0.988826
# 5            0.001253        0.003606         0.001144          0.001026
#
#    distilbert_fear  distilbert_surprise
# 0         0.000143             0.000158
# 1         0.531991             0.000986
# 2         0.000147             0.000130
# 3         0.001107             0.000439
# 4         0.004357             0.000310
# 5         0.002769             0.990202
